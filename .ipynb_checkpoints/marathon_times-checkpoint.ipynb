# %% [markdown]
# ### Predict marathon time given (incomplete) 5k, 10k and half times

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
# Load data
file='data.csv'
data = pd.read_csv(file, index_col=0)
data.head()
# Out:
#     adjusted   age        bmi  cohort1  cohort2  cohort3  cohort4  \
# id
# 1          1  25.0  21.622116      NaN      NaN      NaN      NaN
# 2          1  41.0  23.905970      NaN      NaN      NaN      NaN
# 3          1  25.0  21.640728      NaN      NaN      NaN      NaN
# 4          1  35.0  23.592323      1.0      NaN      NaN      NaN
# 5          1  34.0  22.706404      NaN      NaN      NaN      NaN
#
#     endurancecat  endurancespeed  female     ...       mf_di    mf_ti  \
# id                                           ...
# 1              1               2       1     ...         NaN      NaN
# 2              1               2       0     ...         NaN      NaN
# 3              2               3       0     ...         NaN      NaN
# 4              2               5       0     ...         4.0  10295.0
# 5              2               3       0     ...         NaN      NaN
#
#       mf_ti_adj  mf_tr   max  sprint  tempo  typical  model1_time  model2_time
# id
# 1           NaN    NaN  47.0       1      0     30.0          NaN          NaN
# 2           NaN    NaN  28.0       1      1     23.0          NaN          NaN
# 3           NaN    NaN  70.0       1      1     50.0          NaN          NaN
# 4   10399.02832    1.0  60.0       1      1     50.0          NaN          NaN
# 5           NaN    NaN  15.0       0      0      8.0          NaN          NaN
#
# [5 rows x 49 columns]

# %%
# Filter by:
# adjusted=1 -- not enough races otherwise
# cohort1 == 1 -- otherwise no marathon time
data = data[data['adjusted']==1]
data = data[data['cohort1']==1]
data.head()
# Out:
#     adjusted   age        bmi  cohort1  cohort2  cohort3  cohort4  \
# id
# 4          1  35.0  23.592323      1.0      NaN      NaN      NaN
# 7          1  33.0  22.518295      1.0      1.0      1.0      1.0
# 12         1  38.0  25.560312      1.0      NaN      NaN      NaN
# 13         1  34.0  22.607931      1.0      1.0      NaN      NaN
# 14         1  39.0  24.974836      1.0      1.0      1.0      1.0
#
#     endurancecat  endurancespeed  female     ...       mf_di    mf_ti  \
# id                                           ...
# 4              2               5       0     ...         4.0  10295.0
# 7              2               3       0     ...         3.0  12292.0
# 12             1               2       0     ...         4.0  10980.0
# 13             1               2       0     ...         3.0  10694.0
# 14             3               6       0     ...         2.0  13452.0
#
#        mf_ti_adj  mf_tr   max  sprint  tempo  typical  model1_time  \
# id
# 4   10399.028320    1.0  60.0       1      1     50.0          NaN
# 7   12292.000000    2.0  50.0       0      0     40.0          NaN
# 12  11098.411133    1.0  65.0       0      1     50.0   206.163071
# 13  10694.000000    2.0  88.0       1      1     80.0          NaN
# 14  13387.699219    1.0  51.0       0      1     40.0          NaN
#
#     model2_time
# id
# 4           NaN
# 7           NaN
# 12          NaN
# 13          NaN
# 14          NaN
#
# [5 rows x 49 columns]

# %%
# Drop unwanted columns: 
# endurancespeed, 5 mile and 10 mile data (not enough), predicted results from other models
# Calculated data for 5k, 10k, half and full
data.drop(['endurancespeed', 'm5_d', 'm5_di', 'm5_ti', 'm5_ti_adj', 'm5_tr', \
           'm10_d', 'm10_di', 'm10_ti', 'm10_ti_adj', 'm10_tr', \
           'k5_ti_adj', 'k10_ti_adj', 'mh_ti_adj', 'mf_ti_adj', \
           'adjusted', 'cohort1', 'cohort2', 'cohort3', 'cohort4', \
          'model1_time', 'model2_time', 'group'], axis=1, inplace=True)
data.head()
# Out:
#      age        bmi  endurancecat  female  footwear  injury    k5_d  k5_di  \
# id
# 4   35.0  23.592323             2       0         2       2  5000.0    3.0
# 7   33.0  22.518295             2       0         2       2  5000.0    4.0
# 12  38.0  25.560312             1       0         2       1     NaN    NaN
# 13  34.0  22.607931             1       0         2       1     NaN    NaN
# 14  39.0  24.974836             3       0         2       1  5000.0    4.0
#
#      k5_ti  k5_tr   ...      mh_ti  mh_tr     mf_d  mf_di    mf_ti  mf_tr  \
# id                  ...
# 4   1075.0    1.0   ...        NaN    NaN  42195.0    4.0  10295.0    1.0
# 7   1292.0    3.0   ...     5760.0    2.0  42195.0    3.0  12292.0    2.0
# 12     NaN    NaN   ...        NaN    NaN  42195.0    4.0  10980.0    1.0
# 13     NaN    NaN   ...     4995.0    2.0  42195.0    3.0  10694.0    2.0
# 14  1222.0    1.0   ...     5884.0    1.0  42195.0    2.0  13452.0    1.0
#
#      max  sprint  tempo  typical
# id
# 4   60.0       1      1     50.0
# 7   50.0       0      0     40.0
# 12  65.0       0      1     50.0
# 13  88.0       1      1     80.0
# 14  51.0       0      1     40.0
#
# [5 rows x 26 columns]

# %%
data.dtypes
# Out:
# age             float64
# bmi             float64
# endurancecat      int64
# female            int64
# footwear          int64
# injury            int64
# k5_d            float64
# k5_di           float64
# k5_ti           float64
# k5_tr           float64
# k10_d           float64
# k10_di          float64
# k10_ti          float64
# k10_tr          float64
# mh_d            float64
# mh_di           float64
# mh_ti           float64
# mh_tr           float64
# mf_d            float64
# mf_di           float64
# mf_ti           float64
# mf_tr           float64
# max             float64
# sprint            int64
# tempo             int64
# typical         float64
# dtype: object

# %%
# Compute additional features
# Compute speed (then drop time and distance)
data['k5_s'] = data['k5_d']/data['k5_ti']
data['k10_s'] = data['k10_d']/data['k10_ti']
data['mh_s'] = data['mh_d']/data['mh_ti']
data['mean_s'] = data[['k5_s', 'k10_s', 'mh_s']].mean(axis=1)

data['mf_s'] = data['mf_d']/data['mf_ti']

# %%
# Drop any more fields
data.drop(['k5_d', 'k5_ti', 'k10_d', 'k10_ti', 'mh_d', 'mh_ti', 'mf_d', 'mf_ti'], axis=1, inplace=True)
#data.drop(['k5_ti', 'k10_ti', 'mh_ti', 'mf_ti'], axis=1, inplace=True)

# %%
data.describe()
# Out:
#               age         bmi  endurancecat      female    footwear  \
# count  929.000000  929.000000    929.000000  929.000000  929.000000
# mean    37.328310   23.378063      1.752422    0.361679    1.799785
# std      9.093911    2.854111      0.655758    0.480745    0.433957
# min     20.000000   17.530680      1.000000    0.000000    1.000000
# 25%     31.000000   21.521336      1.000000    0.000000    2.000000
# 50%     35.000000   23.083443      2.000000    0.000000    2.000000
# 75%     43.000000   24.625856      2.000000    1.000000    2.000000
# max     70.000000   47.184647      4.000000    1.000000    3.000000
#
#            injury       k5_di       k5_tr      k10_di      k10_tr     ...      \
# count  929.000000  397.000000  397.000000  268.000000  268.000000     ...
# mean     1.444564    3.193955    1.896725    3.089552    1.940299     ...
# std      0.657676    0.843971    0.726076    0.820730    0.762032     ...
# min      1.000000    1.000000    1.000000    1.000000    1.000000     ...
# 25%      1.000000    3.000000    1.000000    3.000000    1.000000     ...
# 50%      1.000000    3.000000    2.000000    3.000000    2.000000     ...
# 75%      2.000000    4.000000    2.000000    4.000000    2.000000     ...
# max      3.000000    5.000000    4.000000    5.000000    4.000000     ...
#
#             mf_tr         max      sprint       tempo     typical        k5_s  \
# count  929.000000  929.000000  929.000000  929.000000  929.000000  397.000000
# mean     1.684607   53.001292    0.566200    0.669537   41.648547    4.038554
# std      0.647101   19.135593    0.495865    0.470633   16.049241    0.638589
# min      1.000000    3.000000    0.000000    0.000000   10.000000    1.941748
# 25%      1.000000   40.000000    0.000000    0.000000   30.000000    3.673769
# 50%      2.000000   50.000000    1.000000    1.000000   40.000000    4.048583
# 75%      2.000000   62.000000    1.000000    1.000000   50.000000    4.460303
# max      4.000000  140.000000    1.000000    1.000000  120.000000    5.868545
#
#             k10_s        mh_s      mean_s        mf_s
# count  268.000000  654.000000  898.000000  929.000000
# mean     3.763046    3.565577    3.727825    3.254957
# std      0.648497    0.602743    0.646490    0.596153
# min      1.773050    2.129770    1.941748    1.826623
# 25%      3.340018    3.160319    3.266590    2.847166
# 50%      3.803728    3.538959    3.734008    3.240783
# 75%      4.203006    3.935184    4.158291    3.643782
# max      5.434783    5.482718    5.868545    5.176030
#
# [8 rows x 23 columns]

# %%
data.head()
# Out:
#      age        bmi  endurancecat  female  footwear  injury  k5_di  k5_tr  \
# id
# 4   35.0  23.592323             2       0         2       2    3.0    1.0
# 7   33.0  22.518295             2       0         2       2    4.0    3.0
# 12  38.0  25.560312             1       0         2       1    NaN    NaN
# 13  34.0  22.607931             1       0         2       1    NaN    NaN
# 14  39.0  24.974836             3       0         2       1    4.0    1.0
#
#     k10_di  k10_tr    ...     mf_tr   max  sprint  tempo  typical      k5_s  \
# id                    ...
# 4      5.0     1.0    ...       1.0  60.0       1      1     50.0  4.651163
# 7      NaN     NaN    ...       2.0  50.0       0      0     40.0  3.869969
# 12     2.0     3.0    ...       1.0  65.0       0      1     50.0       NaN
# 13     NaN     NaN    ...       2.0  88.0       1      1     80.0       NaN
# 14     NaN     NaN    ...       1.0  51.0       0      1     40.0  4.091653
#
#        k10_s      mh_s    mean_s      mf_s
# id
# 4   4.683841       NaN  4.667502  4.098592
# 7        NaN  3.662760  3.766365  3.432720
# 12  3.875969       NaN  3.875969  3.842896
# 13       NaN  4.223724  4.223724  3.945670
# 14       NaN  3.585571  3.838612  3.136708
#
# [5 rows x 23 columns]

# %%
# Lazily normalise all data together
# Skip for now
#data = data.apply(lambda x: (x - np.mean(x)) / (np.max(x) - np.min(x)))

# %%
data.head()
# Out:
#      age        bmi  endurancecat  female  footwear  injury  k5_di  k5_tr  \
# id
# 4   35.0  23.592323             2       0         2       2    3.0    1.0
# 7   33.0  22.518295             2       0         2       2    4.0    3.0
# 12  38.0  25.560312             1       0         2       1    NaN    NaN
# 13  34.0  22.607931             1       0         2       1    NaN    NaN
# 14  39.0  24.974836             3       0         2       1    4.0    1.0
#
#     k10_di  k10_tr    ...     mf_tr   max  sprint  tempo  typical      k5_s  \
# id                    ...
# 4      5.0     1.0    ...       1.0  60.0       1      1     50.0  4.651163
# 7      NaN     NaN    ...       2.0  50.0       0      0     40.0  3.869969
# 12     2.0     3.0    ...       1.0  65.0       0      1     50.0       NaN
# 13     NaN     NaN    ...       2.0  88.0       1      1     80.0       NaN
# 14     NaN     NaN    ...       1.0  51.0       0      1     40.0  4.091653
#
#        k10_s      mh_s    mean_s      mf_s
# id
# 4   4.683841       NaN  4.667502  4.098592
# 7        NaN  3.662760  3.766365  3.432720
# 12  3.875969       NaN  3.875969  3.842896
# 13       NaN  4.223724  4.223724  3.945670
# 14       NaN  3.585571  3.838612  3.136708
#
# [5 rows x 23 columns]

# %%
# Fillna -- this is problematic
data.fillna(value=0, inplace=True)
data.head()
# Out:
#      age        bmi  endurancecat  female  footwear  injury  k5_di  k5_tr  \
# id
# 4   35.0  23.592323             2       0         2       2    3.0    1.0
# 7   33.0  22.518295             2       0         2       2    4.0    3.0
# 12  38.0  25.560312             1       0         2       1    0.0    0.0
# 13  34.0  22.607931             1       0         2       1    0.0    0.0
# 14  39.0  24.974836             3       0         2       1    4.0    1.0
#
#     k10_di  k10_tr    ...     mf_tr   max  sprint  tempo  typical      k5_s  \
# id                    ...
# 4      5.0     1.0    ...       1.0  60.0       1      1     50.0  4.651163
# 7      0.0     0.0    ...       2.0  50.0       0      0     40.0  3.869969
# 12     2.0     3.0    ...       1.0  65.0       0      1     50.0  0.000000
# 13     0.0     0.0    ...       2.0  88.0       1      1     80.0  0.000000
# 14     0.0     0.0    ...       1.0  51.0       0      1     40.0  4.091653
#
#        k10_s      mh_s    mean_s      mf_s
# id
# 4   4.683841  0.000000  4.667502  4.098592
# 7   0.000000  3.662760  3.766365  3.432720
# 12  3.875969  0.000000  3.875969  3.842896
# 13  0.000000  4.223724  4.223724  3.945670
# 14  0.000000  3.585571  3.838612  3.136708
#
# [5 rows x 23 columns]

# %%
data.dtypes
# Out:
# age             float64
# bmi             float64
# endurancecat      int64
# female            int64
# footwear          int64
# injury            int64
# k5_di           float64
# k5_tr           float64
# k10_di          float64
# k10_tr          float64
# mh_di           float64
# mh_tr           float64
# mf_di           float64
# mf_tr           float64
# max             float64
# sprint            int64
# tempo             int64
# typical         float64
# k5_s            float64
# k10_s           float64
# mh_s            float64
# mean_s          float64
# mf_s            float64
# dtype: object

# %%
# Cast all columns as floats
data_float = data.astype(float)
data_float.dtypes
# Out:
# age             float64
# bmi             float64
# endurancecat    float64
# female          float64
# footwear        float64
# injury          float64
# k5_di           float64
# k5_tr           float64
# k10_di          float64
# k10_tr          float64
# mh_di           float64
# mh_tr           float64
# mf_di           float64
# mf_tr           float64
# max             float64
# sprint          float64
# tempo           float64
# typical         float64
# k5_s            float64
# k10_s           float64
# mh_s            float64
# mean_s          float64
# mf_s            float64
# dtype: object

# %%
#data_simple = data_float
data_simple = data_float[['k5_s', 'k10_s', 'mh_s', 'k5_di', 'k10_di', 'mh_di', 'k5_tr', 'k10_tr', 'mh_tr', 'mean_s', 'mf_s']]
#data_simple = data_simple[data_simple['mh_s'] > 0]
data_simple.head()
# Out:
#         k5_s     k10_s      mh_s  k5_di  k10_di  mh_di  k5_tr  k10_tr  mh_tr  \
# id
# 4   4.651163  4.683841  0.000000    3.0     5.0    0.0    1.0     1.0    0.0
# 7   3.869969  0.000000  3.662760    4.0     0.0    3.0    3.0     0.0    2.0
# 12  0.000000  3.875969  0.000000    0.0     2.0    0.0    0.0     3.0    0.0
# 13  0.000000  0.000000  4.223724    0.0     0.0    3.0    0.0     0.0    2.0
# 14  4.091653  0.000000  3.585571    4.0     0.0    4.0    1.0     0.0    1.0
#
#       mean_s      mf_s
# id
# 4   4.667502  4.098592
# 7   3.766365  3.432720
# 12  3.875969  3.842896
# 13  4.223724  3.945670
# 14  3.838612  3.136708

# %%
# Split train and test
np.random.seed(seed = 42)
msk = np.random.rand(len(data_simple)) < 0.7
data_train = data_simple[msk]
data_test = data_simple[~msk]
print(len(data_train))
print(len(data_test))
# Out:
# 658
# 271

# %%
# Split into x and y
x_train = data_train.drop('mf_s', axis=1).as_matrix()
y_train = pd.DataFrame(data_train['mf_s']).as_matrix()
(n_train, m) = x_train.shape

x_test = data_test.drop('mf_s', axis=1).as_matrix()
y_test = pd.DataFrame(data_test['mf_s']).as_matrix()
n_test = x_train.shape[0]
print(m)
# Out:
# 10

# %%
# Linear regression model
# Parameters
learning_rate = 0.01
training_epochs = 1000
display_step = 50
batch_size = 100

# %%
# Graph input
x = tf.placeholder(tf.float32, shape=[None, m])
y = tf.placeholder(tf.float32, shape=[None, 1])

# Model weights and bias
w = tf.Variable(tf.zeros([m,1]))
b = tf.Variable(tf.zeros([1]))

# Model
y_ = tf.add(tf.matmul(x,w), b)

# %%
print(x.get_shape)
print(y.get_shape)
print(w.get_shape())
print(b.get_shape())
print(y_.get_shape())
data_train.dtypes
# Out:
# <bound method Tensor.get_shape of <tf.Tensor 'Placeholder_26:0' shape=(?, 10) dtype=float32>>
# <bound method Tensor.get_shape of <tf.Tensor 'Placeholder_27:0' shape=(?, 1) dtype=float32>>
# (10, 1)
# (1,)
# (?, 1)
# k5_s      float64
# k10_s     float64
# mh_s      float64
# k5_di     float64
# k10_di    float64
# mh_di     float64
# k5_tr     float64
# k10_tr    float64
# mh_tr     float64
# mean_s    float64
# mf_s      float64
# dtype: object

# %%
# Minimize the squared errors.
loss = tf.reduce_mean(tf.square(y_ - y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate)
train_step = optimizer.minimize(loss)

# %%
# Initializing the variables
init = tf.initialize_all_variables()

# %%
with tf.Session() as sess:
    sess.run(init)
    
    # Train model
    for epoch in range(training_epochs):
        #for (x_t, y_t) in zip(x_train, y_train):
        #print(np.transpose(x_train).shape)
        #print(y_train.shape)
        
        batch_idx = np.random.randint(n_train, size=batch_size)
        x_batch = x_train[batch_idx, :]
        y_batch = y_train[batch_idx, :]


        sess.run(train_step, feed_dict={x: x_batch, y: y_batch})
        
        # Display logs per epoch step
        if (epoch+1) % display_step == 0:
            c = sess.run(loss, feed_dict={x: x_batch, y:y_batch})
            print('Step: ' + str(epoch) + ', loss: ' + str(c))
    
    print('Done')
    loss_train = sess.run(loss, feed_dict={x: x_train, y:y_train})
    print('Train loss: ' + str(loss_train))
    loss_test = sess.run(loss, feed_dict={x: x_test, y:y_test})
    print('Test loss: ' + str(loss_test))
    
    print(w.eval())
    print(b.eval())
    
    y_train_ = sess.run(y_, feed_dict={x:x_train})
    y_test_ = sess.run(y_, feed_dict={x:x_test})
# Out:
# Step: 49, loss: 0.261445
# Step: 99, loss: 0.506981
# Step: 149, loss: 0.323219
# Step: 199, loss: 0.130788
# Step: 249, loss: 0.216605
# Step: 299, loss: 0.391472
# Step: 349, loss: 0.180258
# Step: 399, loss: 0.270471
# Step: 449, loss: 0.213198
# Step: 499, loss: 0.230263
# Step: 549, loss: 0.193621
# Step: 599, loss: 0.0583081
# Step: 649, loss: 0.131936
# Step: 699, loss: 0.315075
# Step: 749, loss: 0.219144
# Step: 799, loss: 0.166643
# Step: 849, loss: 0.178106
# Step: 899, loss: 0.30168
# Step: 949, loss: 0.221584
# Step: 999, loss: 0.0726084
# Done
# Train loss: 0.192289
# Test loss: 0.185212
# [[ 0.07581715]
#  [ 0.05239823]
#  [ 0.1529187 ]
#  [-0.1103207 ]
#  [-0.04905943]
#  [-0.13077851]
#  [-0.06930415]
#  [-0.04653887]
#  [-0.09966356]
#  [ 0.50189173]]
# [ 1.48638833]

# %%
data_train['mf_s_pred'] = y_train_
data_train.head()
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#         k5_s     k10_s      mh_s  k5_di  k10_di  mh_di  k5_tr  k10_tr  mh_tr  \
# id
# 4   4.651163  4.683841  0.000000    3.0     5.0    0.0    1.0     1.0    0.0
# 13  0.000000  0.000000  4.223724    0.0     0.0    3.0    0.0     0.0    2.0
# 14  4.091653  0.000000  3.585571    4.0     0.0    4.0    1.0     0.0    1.0
# 17  0.000000  0.000000  2.954004    0.0     0.0    3.0    0.0     0.0    2.0
# 20  0.000000  0.000000  4.483107    0.0     0.0    3.0    0.0     0.0    1.0
#
#       mean_s      mf_s  mf_s_pred
# id
# 4   4.667502  4.098592   3.734930
# 13  4.223724  3.945670   3.660464
# 14  3.838612  3.136708   3.138110
# 17  2.954004  2.824297   2.829039
# 20  4.483107  3.926212   3.929974
