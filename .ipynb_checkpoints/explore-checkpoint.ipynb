# %% [markdown]
# ### Predict marathon time given (incomplete) 5k, 10k and half times

# %%
# %matplotlib inline
#import matplotlib
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm

import numpy as np
import pandas as pd
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999

from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error

import tensorflow as tf

# %%
# Load data
file='data.csv'
raw_data = pd.read_csv(file, index_col=0)
raw_data.head()
# Out:
#     adjusted   age        bmi  cohort1  cohort2  cohort3  cohort4  \
# id
# 1          1  25.0  21.622116      NaN      NaN      NaN      NaN
# 2          1  41.0  23.905970      NaN      NaN      NaN      NaN
# 3          1  25.0  21.640728      NaN      NaN      NaN      NaN
# 4          1  35.0  23.592323      1.0      NaN      NaN      NaN
# 5          1  34.0  22.706404      NaN      NaN      NaN      NaN
#
#     endurancecat  endurancespeed  female  footwear  group  injury    k5_d  \
# id
# 1              1               2       1         2    2.0       1     NaN
# 2              1               2       0         2    2.0       1  5000.0
# 3              2               3       0         2    2.0       1  5000.0
# 4              2               5       0         2    1.0       2  5000.0
# 5              2               3       0         2    1.0       1  5000.0
#
#     k5_di   k5_ti    k5_ti_adj  k5_tr    k10_d  k10_di  k10_ti   k10_ti_adj  \
# id
# 1     NaN     NaN          NaN    NaN  10000.0     4.0  2798.0  2860.482422
# 2     3.0  1210.0  1210.000000    2.0      NaN     NaN     NaN          NaN
# 3     3.0   994.0   994.000061    2.0      NaN     NaN     NaN          NaN
# 4     3.0  1075.0  1075.000000    1.0  10000.0     5.0  2135.0          NaN
# 5     3.0  1186.0  1186.000000    1.0      NaN     NaN     NaN          NaN
#
#     k10_tr  m5_d  m5_di  m5_ti  m5_ti_adj  m5_tr    m10_d  m10_di  m10_ti  \
# id
# 1      2.0   NaN    NaN    NaN        NaN    NaN  16090.0     4.0  4612.0
# 2      NaN   NaN    NaN    NaN        NaN    NaN      NaN     NaN     NaN
# 3      NaN   NaN    NaN    NaN        NaN    NaN      NaN     NaN     NaN
# 4      1.0   NaN    NaN    NaN        NaN    NaN      NaN     NaN     NaN
# 5      NaN   NaN    NaN    NaN        NaN    NaN  16090.0     4.0  4120.0
#
#      m10_ti_adj  m10_tr     mh_d  mh_di   mh_ti    mh_ti_adj  mh_tr     mf_d  \
# id
# 1   4798.809082     2.0  21097.5    2.0  6320.0  6257.026367    2.0      NaN
# 2           NaN     NaN  21097.5    4.0  5510.0  5654.475586    1.0      NaN
# 3           NaN     NaN  21097.5    3.0  4520.0  4520.000000    2.0      NaN
# 4           NaN     NaN      NaN    NaN     NaN          NaN    NaN  42195.0
# 5   4268.437012     3.0  21097.5    3.0  5475.0  5475.000000    2.0      NaN
#
#     mf_di    mf_ti    mf_ti_adj  mf_tr   max  sprint  tempo  typical  \
# id
# 1     NaN      NaN          NaN    NaN  47.0       1      0     30.0
# 2     NaN      NaN          NaN    NaN  28.0       1      1     23.0
# 3     NaN      NaN          NaN    NaN  70.0       1      1     50.0
# 4     4.0  10295.0  10399.02832    1.0  60.0       1      1     50.0
# 5     NaN      NaN          NaN    NaN  15.0       0      0      8.0
#
#     model1_time  model2_time
# id
# 1           NaN          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4           NaN          NaN
# 5           NaN          NaN

# %%
#raw_data.info()
#raw_data.describe()

# %% [markdown]
# ## Explore data

# %%
data = raw_data.copy()

# %%
# Look at the range of times (in hours)
(data['mf_ti']/3600).hist(bins=10)

# %%
# Look at hm vs fm times
data.plot(x='mh_ti', y='mf_ti', kind='scatter')

# %%
# Look at all times vs fm times
def plot_manyx(df, x_cols, y_col):
    # Plot each (x_col,y) with colour c
    
    colors = cm.rainbow(np.linspace(0,1,len(x_cols)))
    ax = None
    
    for (x_col, color) in zip(x_cols, colors):
        if ax is None:
            ax = df.plot(x=x_col, y=y_col, kind='scatter', title=y_col, color=color)
        else:
            df.plot(x=x_col, y=y_col, kind='scatter', ax=ax, color=color)
    
    plt.legend(x_cols)
    plt.show()

# %%
race_times = ['k5_ti', 'k10_ti', 'm5_ti', 'm10_ti', 'mh_ti', 'mf_ti']
plot_manyx(data, race_times[:-1], race_times[-1])

# %%
# ^^ Unsurprisingly, other race times are correlated with marathon time
# Probably this is just ~ same pace, confirmed below

# %%
# Look at numbers of race times
data[race_times].notnull().sum()
# Out:
# k5_ti     1387
# k10_ti     946
# m5_ti      313
# m10_ti     357
# mh_ti     1579
# mf_ti     1022
# dtype: int64

# %%
# Compute pace (in seconds/metre)
# *1600/60 to get mins/mile

race_dists = ['k5_d', 'k10_d', 'm5_d', 'm10_d', 'mh_d', 'mf_d']
race_paces = []

for race_time, race_dist in zip(race_times, race_dists):
    race_pace = race_dist[:-1] + 'pace'
    race_paces.append(race_pace)
    
    data[race_pace] = data[race_time] / data[race_dist]

# %%
plot_manyx(data, race_paces[:-1], race_paces[-1])

# %%
# All plots ~aligned ==> an individual's pace for a shorter distance is similar to that for marathon

# %% [markdown]
# ## Feature cleaning

# %%
#data[data['adjusted'] == 0][race_times].notnull().sum()

# %%
#data[data['adjusted'] == 0][race_times].head()

# %%
#data[data['cohort1'].isnull()][race_times].head()

# %%
# Filter by:
# adjusted == 1 -- adjusted to exclude very fast or very difficult races
# cohort1 == 1 -- otherwise no marathon time
data = data[data['adjusted']==1]
data = data[data['cohort1']==1]
data.head()
# Out:
#     adjusted   age        bmi  cohort1  cohort2  cohort3  cohort4  \
# id
# 4          1  35.0  23.592323      1.0      NaN      NaN      NaN
# 7          1  33.0  22.518295      1.0      1.0      1.0      1.0
# 12         1  38.0  25.560312      1.0      NaN      NaN      NaN
# 13         1  34.0  22.607931      1.0      1.0      NaN      NaN
# 14         1  39.0  24.974836      1.0      1.0      1.0      1.0
#
#     endurancecat  endurancespeed  female  footwear  group  injury    k5_d  \
# id
# 4              2               5       0         2    1.0       2  5000.0
# 7              2               3       0         2    2.0       2  5000.0
# 12             1               2       0         2    3.0       1     NaN
# 13             1               2       0         2    1.0       1     NaN
# 14             3               6       0         2    1.0       1  5000.0
#
#     k5_di   k5_ti    k5_ti_adj  k5_tr    k10_d  k10_di  k10_ti   k10_ti_adj  \
# id
# 4     3.0  1075.0  1075.000000    1.0  10000.0     5.0  2135.0          NaN
# 7     4.0  1292.0  1299.988647    3.0      NaN     NaN     NaN          NaN
# 12    NaN     NaN          NaN    NaN  10000.0     2.0  2580.0  2563.756348
# 13    NaN     NaN          NaN    NaN      NaN     NaN     NaN          NaN
# 14    4.0  1222.0  1229.144043    1.0      NaN     NaN     NaN          NaN
#
#     k10_tr  m5_d  m5_di  m5_ti  m5_ti_adj  m5_tr    m10_d  m10_di  m10_ti  \
# id
# 4      1.0   NaN    NaN    NaN        NaN    NaN      NaN     NaN     NaN
# 7      NaN   NaN    NaN    NaN        NaN    NaN      NaN     NaN     NaN
# 12     3.0   NaN    NaN    NaN        NaN    NaN      NaN     NaN     NaN
# 13     NaN   NaN    NaN    NaN        NaN    NaN  16090.0     1.0  3896.0
# 14     NaN   NaN    NaN    NaN        NaN    NaN      NaN     NaN     NaN
#
#     m10_ti_adj  m10_tr     mh_d  mh_di   mh_ti    mh_ti_adj  mh_tr     mf_d  \
# id
# 4          NaN     NaN      NaN    NaN     NaN          NaN    NaN  42195.0
# 7          NaN     NaN  21097.5    3.0  5760.0  5760.000000    2.0  42195.0
# 12         NaN     NaN      NaN    NaN     NaN          NaN    NaN  42195.0
# 13         NaN     1.0  21097.5    3.0  4995.0  4995.000000    2.0  42195.0
# 14         NaN     NaN  21097.5    4.0  5884.0  6049.047852    1.0  42195.0
#
#     mf_di    mf_ti     mf_ti_adj  mf_tr   max  sprint  tempo  typical  \
# id
# 4     4.0  10295.0  10399.028320    1.0  60.0       1      1     50.0
# 7     3.0  12292.0  12292.000000    2.0  50.0       0      0     40.0
# 12    4.0  10980.0  11098.411133    1.0  65.0       0      1     50.0
# 13    3.0  10694.0  10694.000000    2.0  88.0       1      1     80.0
# 14    2.0  13452.0  13387.699219    1.0  51.0       0      1     40.0
#
#     model1_time  model2_time
# id
# 4           NaN          NaN
# 7           NaN          NaN
# 12   206.163071          NaN
# 13          NaN          NaN
# 14          NaN          NaN

# %%
# Check performance of existing model1 -- uses 1 prior race
data_model1 = data[data['model1_time'].notnull()]
model1_mae = mean_absolute_error(data_model1.mf_ti/60, data_model1.model1_time)
print('Mean absolute error: %s minutes' % model1_mae)
# Out:
# Mean absolute error: 11.3689177646 minutes

# %%
# Model 2 -- uses 2 prior races
data_model2 = data[data['model2_time'].notnull()]
model2_mae = mean_absolute_error(data_model2.mf_ti/60, data_model2.model2_time)
print('Mean absolute error: %s minutes' % model2_mae)
# Out:
# Mean absolute error: 10.2873906453 minutes

# %%
# Drop unwanted columns: 
# endurancespeed, predicted results from other models
# Calculated data for 5k, 10k, half and full
# Drop 5 mile and 10 mile data (not enough)? Keep for now
data.drop(['k5_ti_adj', 'k10_ti_adj', 'm5_ti_adj', 'm10_ti_adj', 'mh_ti_adj', 'mf_ti_adj', \
           'endurancespeed', 'adjusted', 'cohort1', 'cohort2', 'cohort3', 'cohort4', \
          'model1_time', 'model2_time', 'group'], axis=1, inplace=True)
data.head()
# Out:
#      age        bmi  endurancecat  female  footwear  injury    k5_d  k5_di  \
# id
# 4   35.0  23.592323             2       0         2       2  5000.0    3.0
# 7   33.0  22.518295             2       0         2       2  5000.0    4.0
# 12  38.0  25.560312             1       0         2       1     NaN    NaN
# 13  34.0  22.607931             1       0         2       1     NaN    NaN
# 14  39.0  24.974836             3       0         2       1  5000.0    4.0
#
#      k5_ti  k5_tr    k10_d  k10_di  k10_ti  k10_tr  m5_d  m5_di  m5_ti  m5_tr  \
# id
# 4   1075.0    1.0  10000.0     5.0  2135.0     1.0   NaN    NaN    NaN    NaN
# 7   1292.0    3.0      NaN     NaN     NaN     NaN   NaN    NaN    NaN    NaN
# 12     NaN    NaN  10000.0     2.0  2580.0     3.0   NaN    NaN    NaN    NaN
# 13     NaN    NaN      NaN     NaN     NaN     NaN   NaN    NaN    NaN    NaN
# 14  1222.0    1.0      NaN     NaN     NaN     NaN   NaN    NaN    NaN    NaN
#
#       m10_d  m10_di  m10_ti  m10_tr     mh_d  mh_di   mh_ti  mh_tr     mf_d  \
# id
# 4       NaN     NaN     NaN     NaN      NaN    NaN     NaN    NaN  42195.0
# 7       NaN     NaN     NaN     NaN  21097.5    3.0  5760.0    2.0  42195.0
# 12      NaN     NaN     NaN     NaN      NaN    NaN     NaN    NaN  42195.0
# 13  16090.0     1.0  3896.0     1.0  21097.5    3.0  4995.0    2.0  42195.0
# 14      NaN     NaN     NaN     NaN  21097.5    4.0  5884.0    1.0  42195.0
#
#     mf_di    mf_ti  mf_tr   max  sprint  tempo  typical     dpace  k5_pace  \
# id
# 4     4.0  10295.0    1.0  60.0       1      1     50.0  0.243986   0.2150
# 7     3.0  12292.0    2.0  50.0       0      0     40.0  0.291314   0.2584
# 12    4.0  10980.0    1.0  65.0       0      1     50.0  0.260220      NaN
# 13    3.0  10694.0    2.0  88.0       1      1     80.0  0.253442      NaN
# 14    2.0  13452.0    1.0  51.0       0      1     40.0  0.318806   0.2444
#
#     k10_pace  m5_pace  m10_pace   mh_pace   mf_pace
# id
# 4     0.2135      NaN       NaN       NaN  0.243986
# 7        NaN      NaN       NaN  0.273018  0.291314
# 12    0.2580      NaN       NaN       NaN  0.260220
# 13       NaN      NaN  0.242138  0.236758  0.253442
# 14       NaN      NaN       NaN  0.278896  0.318806

# %%
#data.dtypes

# %%
# Compute mean pace excluding marathon
data['mean_pace'] = data[race_paces[:-1]].mean(axis=1)
data.head()
# Out:
#      age        bmi  endurancecat  female  footwear  injury    k5_d  k5_di  \
# id
# 4   35.0  23.592323             2       0         2       2  5000.0    3.0
# 7   33.0  22.518295             2       0         2       2  5000.0    4.0
# 12  38.0  25.560312             1       0         2       1     NaN    NaN
# 13  34.0  22.607931             1       0         2       1     NaN    NaN
# 14  39.0  24.974836             3       0         2       1  5000.0    4.0
#
#      k5_ti  k5_tr    k10_d  k10_di  k10_ti  k10_tr  m5_d  m5_di  m5_ti  m5_tr  \
# id
# 4   1075.0    1.0  10000.0     5.0  2135.0     1.0   NaN    NaN    NaN    NaN
# 7   1292.0    3.0      NaN     NaN     NaN     NaN   NaN    NaN    NaN    NaN
# 12     NaN    NaN  10000.0     2.0  2580.0     3.0   NaN    NaN    NaN    NaN
# 13     NaN    NaN      NaN     NaN     NaN     NaN   NaN    NaN    NaN    NaN
# 14  1222.0    1.0      NaN     NaN     NaN     NaN   NaN    NaN    NaN    NaN
#
#       m10_d  m10_di  m10_ti  m10_tr     mh_d  mh_di   mh_ti  mh_tr     mf_d  \
# id
# 4       NaN     NaN     NaN     NaN      NaN    NaN     NaN    NaN  42195.0
# 7       NaN     NaN     NaN     NaN  21097.5    3.0  5760.0    2.0  42195.0
# 12      NaN     NaN     NaN     NaN      NaN    NaN     NaN    NaN  42195.0
# 13  16090.0     1.0  3896.0     1.0  21097.5    3.0  4995.0    2.0  42195.0
# 14      NaN     NaN     NaN     NaN  21097.5    4.0  5884.0    1.0  42195.0
#
#     mf_di    mf_ti  mf_tr   max  sprint  tempo  typical  k5_pace  k10_pace  \
# id
# 4     4.0  10295.0    1.0  60.0       1      1     50.0   0.2150    0.2135
# 7     3.0  12292.0    2.0  50.0       0      0     40.0   0.2584       NaN
# 12    4.0  10980.0    1.0  65.0       0      1     50.0      NaN    0.2580
# 13    3.0  10694.0    2.0  88.0       1      1     80.0      NaN       NaN
# 14    2.0  13452.0    1.0  51.0       0      1     40.0   0.2444       NaN
#
#     m5_pace  m10_pace   mh_pace   mf_pace  mean_pace
# id
# 4       NaN       NaN       NaN  0.243986   0.214250
# 7       NaN       NaN  0.273018  0.291314   0.265709
# 12      NaN       NaN       NaN  0.260220   0.258000
# 13      NaN  0.242138  0.236758  0.253442   0.239448
# 14      NaN       NaN  0.278896  0.318806   0.261648

# %%
# Drop any more fields
#data.drop(['k5_d', 'k5_ti', 'k10_d', 'k10_ti', 'mh_d', 'mh_ti', 'mf_d', 'mf_ti'], axis=1, inplace=True)
#data.drop(['k5_ti', 'k10_ti', 'mh_ti', 'mf_ti'], axis=1, inplace=True)

# %%
# Categorise feature cols
personal_cols = ['age', 'endurancecat', 'female', 'footwear', 'injury']
# about the individual

running_cols = ['max', 'sprint', 'tempo', 'typical']
# About running in general

race_difficulties = ['k5_di', 'k10_di', 'm5_di', 'm10_di', 'mh_di', 'mf_di']
race_fitness = ['k5_tr', 'k10_tr', 'm5_tr', 'm10_tr', 'mh_tr', 'mf_tr']
# Already have race_dists, _times, _paces plus 'mean_pace'

# %%
data[race_paces + ['mean_pace']].head()
# Out:
#     k5_pace  k10_pace  m5_pace  m10_pace   mh_pace   mf_pace  mean_pace
# id
# 4    0.2150    0.2135      NaN       NaN       NaN  0.243986   0.214250
# 7    0.2584       NaN      NaN       NaN  0.273018  0.291314   0.265709
# 12      NaN    0.2580      NaN       NaN       NaN  0.260220   0.258000
# 13      NaN       NaN      NaN  0.242138  0.236758  0.253442   0.239448
# 14   0.2444       NaN      NaN       NaN  0.278896  0.318806   0.261648

# %%
data[race_paces + ['mean_pace']].describe()
# Out:
#           k5_pace    k10_pace    m5_pace   m10_pace     mh_pace     mf_pace  \
# count  397.000000  268.000000  67.000000  96.000000  654.000000  929.000000
# mean     0.254702    0.274658   0.269083   0.276520    0.288857    0.318234
# std      0.046645    0.054017   0.062661   0.057551    0.051238    0.062182
# min      0.170400    0.184000   0.175016   0.192977    0.182391    0.193198
# 25%      0.224200    0.237925   0.222809   0.237415    0.254118    0.274440
# 50%      0.247000    0.262900   0.253574   0.267526    0.282569    0.308567
# 75%      0.272200    0.299400   0.298322   0.293474    0.316424    0.351226
# max      0.515000    0.564000   0.457054   0.503418    0.469534    0.547458
#
#         mean_pace
# count  929.000000
# mean     0.277341
# std      0.052038
# min      0.175016
# 25%      0.241100
# 50%      0.268275
# 75%      0.304484
# max      0.515000

# %%
data[race_paces + ['mean_pace']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 929 entries, 4 to 2171
# Data columns (total 7 columns):
# k5_pace      397 non-null float64
# k10_pace     268 non-null float64
# m5_pace      67 non-null float64
# m10_pace     96 non-null float64
# mh_pace      654 non-null float64
# mf_pace      929 non-null float64
# mean_pace    929 non-null float64
# dtypes: float64(7)
# memory usage: 58.1 KB

# %% [markdown]
# ## Train quick LR model
# Predict marathon pace from mean pace

# %%
# Split into train/test/holdout
seed=1

holdout_frac = 0.1
data_traintest, data_holdout = train_test_split(data, test_size=holdout_frac, random_state=seed)

test_frac = 0.2
data_train, data_test = train_test_split(data_traintest, test_size=test_frac, random_state=seed)

# %%
# Get x and y from the df
def get_xy(df, y_col, x_cols=None):
    # Return x and y arrays from df
    if x_cols is None:
        x = df.drop(y_col, axis=1).values
    else:
        x = df[x_cols].values
        
    y = df[y_col].values
    
    return (x,y)

# %%
# Use only mean_pace column to predict
x_train, y_train = get_xy(data_train, 'mf_pace', 'mean_pace')
x_test, y_test = get_xy(data_test, 'mf_pace', 'mean_pace')
print(x_train.shape, y_train.shape)
print(x_test.shape)
# Out:
# (668,) (668,)
# (168,)

# %%
# Reshape x since only one feature
x_train = x_train.reshape((-1,1))
x_test = x_test.reshape((-1,1))

print(x_train.shape, x_test.shape)
# Out:
# (668, 1) (168, 1)

# %%
# Train model
ridge_model = Ridge(random_state=seed)
ridge_model.fit(x_train, y_train)
# Out:
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)

# %%
# Predict and get score
y_train_pred = ridge_model.predict(x_train)
y_test_pred = ridge_model.predict(x_test)

y_train_score = ridge_model.score(x_train, y_train)
y_test_score = ridge_model.score(x_test, y_test)

# %%
print(y_train_score)
print(y_test_score)
# Out:
# 0.682539535842
# 0.67645338922

# %%
# Look at predictions
data_test['mf_pace_pred'] = y_test_pred
data_test['mf_ti_pred'] = data_test['mf_pace_pred']*data_test['mf_d']
data_test['mf_ti_pred_error'] = data_test['mf_ti_pred'] - data_test['mf_ti']
data_test.head()
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#        age        bmi  endurancecat  female  footwear  injury    k5_d  k5_di  \
# id
# 1740  32.0  24.489796             3       0         2       1  5000.0    3.0
# 860   49.0  20.899574             1       1         2       2     NaN    NaN
# 216   38.0  20.419033             2       1         2       2     NaN    NaN
# 1345  37.0  24.526159             2       0         2       1     NaN    NaN
# 155   29.0  27.197418             2       1         2       2  5000.0    4.0
#
#        k5_ti  k5_tr  k10_d  k10_di  k10_ti  k10_tr    m5_d  m5_di   m5_ti  \
# id
# 1740   985.0    2.0    NaN     NaN     NaN     NaN     NaN    NaN     NaN
# 860      NaN    NaN    NaN     NaN     NaN     NaN     NaN    NaN     NaN
# 216      NaN    NaN    NaN     NaN     NaN     NaN  8045.0    2.0  2135.0
# 1345     NaN    NaN    NaN     NaN     NaN     NaN     NaN    NaN     NaN
# 155   1660.0    1.0    NaN     NaN     NaN     NaN     NaN    NaN     NaN
#
#       m5_tr  m10_d  m10_di  m10_ti  m10_tr     mh_d  mh_di   mh_ti  mh_tr  \
# id
# 1740    NaN    NaN     NaN     NaN     NaN  21097.5    2.0  4528.0    1.0
# 860     NaN    NaN     NaN     NaN     NaN  21097.5    3.0  5840.0    2.0
# 216     2.0    NaN     NaN     NaN     NaN  21097.5    3.0  5868.0    2.0
# 1345    NaN    NaN     NaN     NaN     NaN  21097.5    3.0  5292.0    2.0
# 155     NaN    NaN     NaN     NaN     NaN  21097.5    2.0  8007.0    2.0
#
#          mf_d  mf_di    mf_ti  mf_tr   max  sprint  tempo  typical  k5_pace  \
# id
# 1740  42195.0    2.0   9787.0    1.0  83.0       0      1     65.0    0.197
# 860   42195.0    3.0  12363.0    2.0  67.0       1      0     45.0      NaN
# 216   42195.0    2.0  13120.0    1.0  62.0       1      1     55.0      NaN
# 1345  42195.0    3.0  11262.0    2.0  75.0       0      1     60.0      NaN
# 155   42195.0    3.0  17341.0    1.0  44.0       0      0     35.0    0.332
#
#       k10_pace   m5_pace  m10_pace   mh_pace   mf_pace  mean_pace  \
# id
# 1740       NaN       NaN       NaN  0.214623  0.231947   0.205811
# 860        NaN       NaN       NaN  0.276810  0.292997   0.276810
# 216        NaN  0.265382       NaN  0.278137  0.310937   0.271760
# 1345       NaN       NaN       NaN  0.250835  0.266904   0.250835
# 155        NaN       NaN       NaN  0.379524  0.410973   0.355762
#
#       mf_pace_pred    mf_ti_pred  mf_pace_pred_error  mf_ti_pred_error
# id
# 1740      0.270274  11404.232173            0.038328       1617.232173
# 860       0.318164  13424.930433            0.025167       1061.930433
# 216       0.314758  13281.192913            0.003820        161.192913
# 1345      0.300644  12685.665182            0.033740       1423.665182
# 155       0.371418  15671.979773           -0.039555      -1669.020227

# %%
mf_ti_mae_test = mean_absolute_error(data_test.mf_ti, data_test.mf_ti_pred)
print('Mean absolute error: %s minutes' % (mf_ti_mae_test/60))
# Out:
# Mean absolute error: 20.1214940698 minutes

# %%
# ^^ Not amazing but not a bad start. Existing model is 10-11 mins.

# %%
# Look at coefficients
print(ridge_model.coef_)
print(ridge_model.intercept_)
# Out:
# [ 0.67451209]
# 0.131452286409

# %% [markdown]
# ### Try predicting only with half marathon time

# %%
# Lazily keep same train/test split, just drop rows without half marathon time
data_train_mh = data_train[data_train['mh_ti'].notnull()]
print('Train data reduced from %s to %s' % (len(data_train), len(data_train_mh)))

data_test_mh = data_test[data_test['mh_ti'].notnull()]
print('Test data reduced from %s to %s' % (len(data_test), len(data_test_mh)))
# Out:
# Train data reduced from 668 to 469
# Test data reduced from 168 to 120

# %%
# Use only mh pace column to predict
x_train_mh, y_train_mh = get_xy(data_train_mh, 'mf_pace', 'mh_pace')
x_test_mh, y_test_mh = get_xy(data_test_mh, 'mf_pace', 'mh_pace')
print(x_train_mh.shape, y_train_mh.shape)
print(x_test_mh.shape)
# Out:
# (469,) (469,)
# (120,)

# %%
# Reshape x since only one feature
x_train_mh = x_train_mh.reshape((-1,1))
x_test_mh = x_test_mh.reshape((-1,1))

print(x_train_mh.shape, x_test_mh.shape)
# Out:
# (469, 1) (120, 1)

# %%
# Train model
ridge_model_mh = Ridge(random_state=seed)
ridge_model_mh.fit(x_train_mh, y_train_mh)
# Out:
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=1, solver='auto', tol=0.001)

# %%
# Predict and get score
y_train_pred_mh = ridge_model.predict(x_train_mh)
y_test_pred_mh = ridge_model.predict(x_test_mh)

y_train_score_mh = ridge_model.score(x_train_mh, y_train_mh)
y_test_score_mh = ridge_model.score(x_test_mh, y_test_mh)

# %%
# Look at predictions
data_test_mh['mf_pace_pred'] = y_test_pred_mh
data_test_mh['mf_ti_pred'] = data_test_mh['mf_pace_pred']*data_test_mh['mf_d']
data_test_mh['mf_ti_pred_error'] = data_test_mh['mf_ti_pred'] - data_test_mh['mf_ti']
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
mf_ti_mae_test_mh = mean_absolute_error(data_test_mh.mf_ti, data_test_mh.mf_ti_pred)
print('Mean absolute error: %s minutes' % (mf_ti_mae_test_mh/60))
# Out:
# Mean absolute error: 20.3484918876 minutes

# %%
# ^^ No different from mean model, interesting

# %%
# Look at coefficients
print(ridge_model_mh.coef_)
print(ridge_model_mh.intercept_)
# Out:
# [ 0.60354937]
# 0.146236722848

# %% [markdown]
# ## TODO
# * Investigate how best to use the shorter race times
# * Make use of other features
# * ...

# %% [markdown]
# ### Playing with TF

# %%
# Lazily normalise all data together
# Skip for now
#data = data.apply(lambda x: (x - np.mean(x)) / (np.max(x) - np.min(x)))

# %%
data.head()

# %%
# Fillna -- this is problematic
data.fillna(value=0, inplace=True)
data.head()

# %%
data.dtypes

# %%
# Cast all columns as floats
data_float = data.astype(float)
data_float.dtypes

# %%
#data_simple = data_float
data_simple = data_float[['k5_s', 'k10_s', 'mh_s', 'k5_di', 'k10_di', 'mh_di', 'k5_tr', 'k10_tr', 'mh_tr', 'mean_s', 'mf_s']]
#data_simple = data_simple[data_simple['mh_s'] > 0]
data_simple.head()

# %%
# Split train and test
np.random.seed(seed = 42)
msk = np.random.rand(len(data_simple)) < 0.7
data_train = data_simple[msk]
data_test = data_simple[~msk]
print(len(data_train))
print(len(data_test))

# %%
# Split into x and y
x_train = data_train.drop('mf_s', axis=1).as_matrix()
y_train = pd.DataFrame(data_train['mf_s']).as_matrix()
(n_train, m) = x_train.shape

x_test = data_test.drop('mf_s', axis=1).as_matrix()
y_test = pd.DataFrame(data_test['mf_s']).as_matrix()
n_test = x_train.shape[0]
print(m)

# %%
# Linear regression model
# Parameters
learning_rate = 0.01
training_epochs = 1000
display_step = 50
batch_size = 100

# %%
# Graph input
x = tf.placeholder(tf.float32, shape=[None, m])
y = tf.placeholder(tf.float32, shape=[None, 1])

# Model weights and bias
w = tf.Variable(tf.zeros([m,1]))
b = tf.Variable(tf.zeros([1]))

# Model
y_ = tf.add(tf.matmul(x,w), b)

# %%
print(x.get_shape)
print(y.get_shape)
print(w.get_shape())
print(b.get_shape())
print(y_.get_shape())
data_train.dtypes

# %%
# Minimize the squared errors.
loss = tf.reduce_mean(tf.square(y_ - y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate)
train_step = optimizer.minimize(loss)

# %%
# Initializing the variables
init = tf.initialize_all_variables()

# %%
with tf.Session() as sess:
    sess.run(init)
    
    # Train model
    for epoch in range(training_epochs):
        #for (x_t, y_t) in zip(x_train, y_train):
        #print(np.transpose(x_train).shape)
        #print(y_train.shape)
        
        batch_idx = np.random.randint(n_train, size=batch_size)
        x_batch = x_train[batch_idx, :]
        y_batch = y_train[batch_idx, :]


        sess.run(train_step, feed_dict={x: x_batch, y: y_batch})
        
        # Display logs per epoch step
        if (epoch+1) % display_step == 0:
            c = sess.run(loss, feed_dict={x: x_batch, y:y_batch})
            print('Step: ' + str(epoch) + ', loss: ' + str(c))
    
    print('Done')
    loss_train = sess.run(loss, feed_dict={x: x_train, y:y_train})
    print('Train loss: ' + str(loss_train))
    loss_test = sess.run(loss, feed_dict={x: x_test, y:y_test})
    print('Test loss: ' + str(loss_test))
    
    print(w.eval())
    print(b.eval())
    
    y_train_ = sess.run(y_, feed_dict={x:x_train})
    y_test_ = sess.run(y_, feed_dict={x:x_test})

# %%
data_train['mf_s_pred'] = y_train_
data_train.head()
